# %%
import datetime as dt
import numpy as np
import pandas as pd
import numpy as np
import tabulate as tb
from typing import Dict
import tensorflow as tf
import re
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score, f1_score
from tensorflow.keras.applications import MobileNetV2

SEED = 42
np.random.seed(SEED)

# %%
df = pd.read_csv('./../data/wta.csv')
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d %H:%M:%S', errors='coerce')
df['Date'].dropna(inplace=True)
df['Date'] = df['Date'].apply(lambda x: x.replace(day=1))

print(tb.tabulate(df.head(10), headers='keys', tablefmt='psql'))
players = df['Player_1'].values.tolist() + df['Player_2'].values.tolist()
players = list(set(players))
print(players)

surfaces = df['Surface'].unique()
print(surfaces)

min_date = df['Date'].min()
max_date = df['Date'].max()
months_range = pd.date_range(start=min_date + pd.DateOffset(months=1), end=max_date, freq='ME')
print(f"Processing months: {months_range.strftime('%Y-%m')}")
# Out:
# C:\Users\BPX Michał Dziedziak\AppData\Local\Temp\ipykernel_22228\4256961432.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./../data/wta.csv')
# +----+--------------+---------------------+---------+-----------+-----------+-----------+---------------+--------------+---------------+----------+----------+---------+---------+---------+---------+-------------+
# |    | Tournament   | Date                | Court   | Surface   | Round     |   Best of | Player_1      | Player_2     | Winner        |   Rank_1 |   Rank_2 |   Pts_1 |   Pts_2 |   Odd_1 |   Odd_2 | Score       |
# |----+--------------+---------------------+---------+-----------+-----------+-----------+---------------+--------------+---------------+----------+----------+---------+---------+---------+---------+-------------|
# ...

# %%
# initialize data
dic = {}

for month in months_range:
    month = month.replace(day=1)
    for player in players:
        for surface in surfaces:
            key = f"{player}_{surface}_{month.strftime('%Y-%m')}"
            dic[key] = {
                'Player': player,
                'Surface': surface,
                'Month': month,

                'EloAll': 1500.0,
                'MatchesAll': 0,
                'WinsAll': 0,
                'LossesAll': 0,
                'WinRateAll': 0.0,

                'EloMonth': 1500.0,
                'MatchesMonth': 0,
                'WinsMonth': 0,
                'LossesMonth': 0,
                'WinRateMonth': 0.0
            }

# %%
def calculate_elo_change(p1_elo, p2_elo, winner: int):
    k = 32
    # k = 256
    expected_p1 = 1 / (1 + 10 ** ((p2_elo - p1_elo) / 400))
    expected_p2 = 1 - expected_p1
    if winner == 1:
        p1_new = p1_elo + k * (1 - expected_p1)
        p2_new = p2_elo + k * (0 - expected_p2)
    else:
        p1_new = p1_elo + k * (0 - expected_p1)
        p2_new = p2_elo + k * (1 - expected_p2)
    return p1_new, p2_new

def find_last_data(player, surface, end_date):
    month = end_date.replace(day=1)
    while True:
        key = f"{player}_{surface}_{month.strftime('%Y-%m')}"
        
        if key not in dic:
            return None
        
        if dic[key]['MatchesAll'] != 0:
            return dic[key]

        month = month - pd.DateOffset(months=1)
        month = month.replace(day=1)
    
    
def update_data(month, row):
    player1 = row['Player_1']
    player2 = row['Player_2']
    surface = row['Surface']
    winner = row['Winner']
    
    prev_month = month - pd.DateOffset(months=1)
    prev_month = prev_month.replace(day=1)
    
    key1 = f"{player1}_{surface}_{month.strftime('%Y-%m')}"
    key2 = f"{player2}_{surface}_{month.strftime('%Y-%m')}"

    p1_prev = find_last_data(player1, surface, prev_month)
    p2_prev = find_last_data(player2, surface, prev_month)
        
    if key1 not in dic or key2 not in dic:
        print(f"Missing data for {key1} or {key2}. Skipping update.")
        return
    
    if dic[key1]['MatchesAll'] == 0 and p1_prev != None:
        dic[key1]['MatchesAll'] = p1_prev['MatchesAll']
        dic[key1]['WinsAll'] = p1_prev['WinsAll']
        dic[key1]['LossesAll'] = p1_prev['LossesAll']
        dic[key1]['EloAll'] = p1_prev['EloAll']
    if dic[key2]['MatchesAll'] == 0 and p2_prev != None:
        dic[key2]['MatchesAll'] = p2_prev['MatchesAll']
        dic[key2]['WinsAll'] = p2_prev['WinsAll']
        dic[key2]['LossesAll'] = p2_prev['LossesAll']
        dic[key2]['EloAll'] = p2_prev['EloAll']
    
    if winner == player1:
        dic[key1]['WinsMonth'] += 1
        dic[key2]['LossesMonth'] += 1
        dic[key1]['EloMonth'], dic[key2]['EloMonth'] = calculate_elo_change(
            dic[key1]['EloMonth'], dic[key2]['EloMonth'], 1)
        
        dic[key1]['WinsAll'] += 1
        dic[key2]['LossesAll'] += 1
        dic[key1]['EloAll'], dic[key2]['EloAll'] = calculate_elo_change(
            dic[key1]['EloAll'], dic[key2]['EloAll'], 1)
    else:
        dic[key1]['LossesMonth'] += 1
        dic[key2]['WinsMonth'] += 1
        dic[key1]['EloMonth'], dic[key2]['EloMonth'] = calculate_elo_change(
            dic[key1]['EloMonth'], dic[key2]['EloMonth'], 2)
        
        dic[key1]['LossesAll'] += 1
        dic[key2]['WinsAll'] += 1
        dic[key1]['EloAll'], dic[key2]['EloAll'] = calculate_elo_change(
            dic[key1]['EloAll'], dic[key2]['EloAll'], 2)
        
    dic[key1]['MatchesMonth'] += 1
    dic[key2]['MatchesMonth'] += 1
    dic[key1]['WinRateMonth'] = dic[key1]['WinsMonth'] / dic[key1]['MatchesMonth']
    dic[key2]['WinRateMonth'] = dic[key2]['WinsMonth'] / dic[key2]['MatchesMonth']
    
    dic[key1]['MatchesAll'] += 1
    dic[key2]['MatchesAll'] += 1
    dic[key1]['WinRateAll'] = dic[key1]['WinsAll'] / dic[key1]['MatchesAll']
    dic[key2]['WinRateAll'] = dic[key2]['WinsAll'] / dic[key2]['MatchesAll']

# %%
prev_month = df['Date'].min().replace(day=1)

for month in months_range:
    month = month.replace(day=1)
    period_df = df[
        (df['Date'] < month) 
        & (df['Date'] >= prev_month)]
    
    for index, row in period_df.iterrows():
        update_data(month, row)
        
    prev_month = month

# %%
prev_month = df['Date'].min().replace(day=1)
for month in months_range:
    month = month.replace(day=1)
    for surface in surfaces:
        for player in players:
            key = f"{player}_{surface}_{month.strftime('%Y-%m')}"
            key_prev = f"{player}_{surface}_{prev_month.strftime('%Y-%m')}"
            
            if key_prev not in dic:
                continue
            
            if dic[key]['MatchesAll'] != 0:
                continue
            
            dic[key]['MatchesAll'] = dic[key_prev]['MatchesAll']
            dic[key]['WinsAll'] = dic[key_prev]['WinsAll']
            dic[key]['LossesAll'] = dic[key_prev]['LossesAll']
            dic[key]['EloAll'] = dic[key_prev]['EloAll']
            dic[key]['WinRateAll'] = dic[key]['WinsAll'] / dic[key]['MatchesAll'] if dic[key]['MatchesAll'] > 0 else 0.0

    prev_month = month

# %%
players_data = pd.DataFrame.from_dict(dic, orient='index')
players_data.to_csv('./../data/players_data.csv', index=False)

tmp = players_data[
    (players_data["Player"] == "Swiatek I.")
    ].sort_values(by='Month', ascending=False).head(20)
print(tb.tabulate(tmp, headers='keys', tablefmt='psql'))
# Out:
# +-----------------------------+------------+-----------+---------------------+----------+--------------+-----------+-------------+--------------+------------+----------------+-------------+---------------+----------------+
# |                             | Player     | Surface   | Month               |   EloAll |   MatchesAll |   WinsAll |   LossesAll |   WinRateAll |   EloMonth |   MatchesMonth |   WinsMonth |   LossesMonth |   WinRateMonth |
# |-----------------------------+------------+-----------+---------------------+----------+--------------+-----------+-------------+--------------+------------+----------------+-------------+---------------+----------------|
# | Swiatek I._Greenset_2025-06 | Swiatek I. | Greenset  | 2025-06-01 00:00:00 |  1500    |            0 |         0 |           0 |     0        |    1500    |              0 |           0 |             0 |       0        |
# ...
