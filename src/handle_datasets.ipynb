# %%
import datetime as dt
import numpy as np
import pandas as pd
import numpy as np
import tabulate as tb
from typing import Dict
import tensorflow as tf
import re
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, GlobalAveragePooling2D
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score, f1_score
from tensorflow.keras.applications import MobileNetV2

SEED = 42
np.random.seed(SEED)

# CURRENT_DATE = dt.datetime.now()
CURRENT_DATE = dt.datetime(2025, 7, 1)

# %%
df = pd.read_csv('./../data/wta.csv')
df['Date'] = pd.to_datetime(df['Date'], format='%Y-%m-%d %H:%M:%S', errors='coerce')
df['Date'].dropna(inplace=True)

print(tb.tabulate(df.head(10), headers='keys', tablefmt='psql'))
players = df['Player_1'].values.tolist() + df['Player_2'].values.tolist()
players = list(set(players))
print(players)

surfaces = df['Surface'].unique()
print(surfaces)
# Out:
# +----+--------------+---------------------+---------+-----------+-----------+-----------+---------------+--------------+---------------+----------+----------+---------+---------+---------+---------+-------------+
# |    | Tournament   | Date                | Court   | Surface   | Round     |   Best of | Player_1      | Player_2     | Winner        |   Rank_1 |   Rank_2 |   Pts_1 |   Pts_2 |   Odd_1 |   Odd_2 | Score       |
# |----+--------------+---------------------+---------+-----------+-----------+-----------+---------------+--------------+---------------+----------+----------+---------+---------+---------+---------+-------------|
# |  0 | ASB Classic  | 2007-01-01 00:00:00 | Outdoor | Hard      | 1st Round |         3 | Sun T.T.      | Baker L.     | Sun T.T.      |       81 |      272 |     332 |      90 |    1.33 |    3    | 6-1 6-1     |
# |  1 | ASB Classic  | 2007-01-01 00:00:00 | Outdoor | Hard      | 1st Round |         3 | Myskina A.    | Dulko G.     | Dulko G.      |       16 |       59 |    1000 |     401 |    1.22 |    3.75 | 1-6 7-6 2-6 |
# |  2 | ASB Classic  | 2007-01-01 00:00:00 | Outdoor | Hard      | 1st Round |         3 | Loit E.       | Birnerova E. | Loit E.       |       56 |       84 |     418 |     324 |    1.72 |    2    | 6-1 6-1     |
# |  3 | ASB Classic  | 2007-01-01 00:00:00 | Outdoor | Hard      | 1st Round |         3 | Nakamura A.   | Craybas J.   | Craybas J.    |       57 |       70 |     405 |     365 |    1.83 |    1.83 | 5-7 2-6     |
# |  4 | ASB Classic  | 2007-01-01 00:00:00 | Outdoor | Hard      | 1st Round |         3 | Bartoli M.    | Morita A.    | Bartoli M.    |       18 |      180 |     951 |     152 |    1.16 |    4.5  | 7-6 6-3     |
# |  5 | ASB Classic  | 2007-01-01 00:00:00 | Outdoor | Hard      | 1st Round |         3 | Perry S.      | Pin C.       | Pin C.        |       44 |       75 |     455 |     349 |    1.5  |    2.5  | 3-6 7-5 2-6 |
# |  6 | ASB Classic  | 2007-01-01 00:00:00 | Outdoor | Hard      | 1st Round |         3 | Daniilidou E. | Kostanic J.  | Daniilidou E. |       36 |       51 |     538 |     422 |    1.36 |    2.87 | 6-3 4-6 6-1 |
# |  7 | ASB Classic  | 2007-01-01 00:00:00 | Outdoor | Hard      | 1st Round |         3 | Tu M.         | Erakovic M.  | Erakovic M.   |       90 |      162 |     312 |     171 |    1.5  |    2.5  | 3-6 6-4 5-7 |
# |  8 | ASB Classic  | 2007-01-01 00:00:00 | Outdoor | Hard      | 1st Round |         3 | Razzano V.    | Kanepi K.    | Razzano V.    |       88 |       78 |     319 |     343 |    1.83 |    1.83 | 7-6 6-1     |
# |  9 | ASB Classic  | 2007-01-01 00:00:00 | Outdoor | Hard      | 1st Round |         3 | Johansson M.  | Laine E.     | Laine E.      |      140 |       74 |     204 |     349 |    2.37 |    1.53 | 6-7 1-6     |
# +----+--------------+---------------------+---------+-----------+-----------+-----------+---------------+--------------+---------------+----------+----------+---------+---------+---------+---------+-------------+
# ['Arruabarrena-Vecino L.', 'Fita Boluda A.', 'Bandecchi S.', 'Bouzkova M.', 'Tatishvili A.', 'Reix S.', 'Ostapenko J.', 'Stosur S.', 'Yoo M.', 'Leykina P.', 'Minor B.', 'Rus A.', 'Dushevina V.', 'Bratchikova N.', 'Czink M. ', 'Bai A.', 'Appleton E.', 'Georgatou E.', 'Kerber A.', 'Bolkvadze M.', 'Chvojkova V.', 'Rampre P.', 'Rueffer L.', 'Guarachi A.', 'Melander H.', 'Ren Y.', 'Makarova E.', 'Sugiyama A.', 'Jovanovski B.', 'Ce G.', 'Hozumi E.', 'Pavlovic I.', 'Hatouka Y.', 'Folts A.', 'Dementieva E.', 'Marrero M.', 'Duque-Marino M.', 'Kucova K.', 'Raina A.', 'Gatto-Monticone G.', 'Vikhlyantseva N.', 'Dart H.', 'Sanders S.', 'Anisimova A.', 'Zhou Y.M.', 'Yang V.', 'Thandi K.', 'Sebov K.', 'Vinci R.', 'Rogers S.', 'Kabbaj Y.', 'Mertens E.', 'Pochabova M.', 'Schmiedlova K.', 'Hogenkamp R.', 'Milevskaya K.', 'Rodriguez V.', 'Zhang L.', 'Fondevila Castro P.', 'Buryachok I.', 'Higuita Barraza M.', 'Lu Jing-Jing', 'Hovde L.', 'Kolar N.', 'Govortsova O.', 'Pous-T. L.', 'Ferguson S.', 'Andreeva E.', 'Halep S.', 'Castiblanco K.', 'Haddad Maia B.', 'Schnyder P.', 'Yan Z.', 'Solovieva V.', 'Garbin T.', 'Cepelova J.', 'Papadakis L.', 'Noel A.', 'Volynets K.', 'Date Krumm K. ', 'Marcinko P.', 'Sierra S.', 'Caregaro M.', 'Van Uytvanck A.', 'Torres Sandoval M.', 'Sugnaux T.', 'Spiteri D.', 'Bondarenko K.', 'Lao D.', 'Xu M.', 'Cecil M.', 'Simmonds C.', 'Laskutova K.', 'Henin J.', 'Kostic N.', 'Di Sarra F.', 'Pliskova Kar.', 'Wang M.', 'Ahn K.H.', 'Khazaniuk D.', 'Ramialison I.', 'Rakhimova K.', 'Bassols M.', 'Konta J.', 'Osuigwe W.', 'Alves C.M.', 'Sharapova, M.', 'Okamura K.', 'Celik S.', 'Garland J.', 'Vrljic A.', 'Pous-T L.', 'Mrdeza T.', 'Fichman S.', 'Compostizode E.', 'Zander N.', 'Wang Xin.', 'Erakovic M.', 'Ivakhnenko V.', 'Hendler T.', 'Glatch A.', 'Samsonova L.', 'Naito Y.', 'Mendez S.', 'Radisic N.', 'Han N.L.', 'Savranska Y.', 'Lottner A.', 'Kutuzova V.', 'Shi H.', 'Jang S.J.', 'Tig P.M.', 'Xu S.', 'Bennani L.', 'Bronzetti L.', 'Cepede Royg V.', 'Burdette M.', 'Kung L.', 'Majeric T.', 'Rolle A.', 'Liggan K.', 'Silva E.', 'Gorgodze E.', 'Dominguez Lino L.', 'Pliskova K.', 'Buyukakcay C.', 'Konjuh A.', 'Sequera M.', 'Date-Krumm K.', 'Song S.S.', 'Sabalenka A.', 'Soler Espinosa S.', 'Lu Jing Jing', 'Lertpitaksinchai N.', 'Zhao Y.J.', 'Cavaday N.', 'Bacsinszky T.', 'Schaefer A.', 'Day K.', 'Mboko V.', 'Disderi S.', 'Poutchek T.', 'Parks A.', 'Nagy K.', 'Martinez-Sanchez M.J.', 'Harrison Ca.', 'Volodko K.', 'Wienerova L.', 'Gibson T.', 'Parrizas Diaz N.', 'Sonobe W.', 'Bogdan A.', 'Serban R.', 'Bai Z.', 'Lucic-Baroni M.', 'Rao S.', 'Cabeza Candela E.', 'Capurro Taborda M.', 'Pridankina E.', 'Kostova E.', 'Pous-Tio L.', 'Ngounoue C.', 'Kessler M.', 'Mayr P.', 'Jankovic J.', 'Jeong B.', 'Chong E.', 'Botto B.', 'Tsurenko L.', 'Saidkhodjaeva D.', 'Sramkova R.', 'Rosatello C.', 'Washington M.', 'Dokic J.', 'Zoric N.', 'Watson H.', 'Ianchuk O.', 'Okuno A.', 'Kozlova K.', 'Dubois S.', 'Hrdinova E.', 'Jiang X.', 'Pereira T.', 'You X.', 'Pieri T.', 'Sakatsume H.', 'Korpatsch T.', 'Danilina A.', 'Sherif M.', 'Bondar A.', 'Rakotomanga Rajaonah T.', 'Sema Y.', 'Badosa Gibert. P.', 'Flink V.', 'Date K.', 'Wang Xiyu', 'Soler Espinosa S..', 'Uberoi N.', 'Sharapova M.', 'Munoz Gallegos D.', 'Sonmez Z.', 'Von Deichmann K.', 'Hlavackova A.', 'Kawa K.', 'Moser L.M.', 'Kremen I.', 'Timofeeva M.', 'Gjorcheska L.', 'Mchale C.', 'Hoch E.', 'Sorribes Tormo S.', 'Pratt N.', 'Fruhvirtova L.', 'Harkleroad A.', 'Savchuk O.', 'Choi J-H.', 'Nara K.', 'Petkovic A.', 'Koch Benvenuto K.A.', 'Bartoli M.', 'Soboleva A.', 'Semenistaja D.', 'Yuan Y.', 'Gerasimou A.', 'Herazo M.', 'Monnet C.', 'Ondraskova Z.', 'Jani R-L.', 'Siniakova K.', 'Contreras Gomez F.', 'Pous Tio L.', 'Smashnovai A.', 'Laisne K.', 'Saville D.', 'Clijsters K.', 'Duque Marino M.', 'Giovine C.', 'Hladikova T.', 'Peer S. ', 'Ruutel M.', 'Jovic I.', 'Matoula M.', 'Soler-Espinosa S.', 'Ewald W.', 'Naydenova A.', 'Osterloh L.', 'Radanovic D.', 'Martinez Granados C.', 'Gonzalez M.', 'Bechri C.', 'Tan H.', 'Wi ...
# ['Hard' 'Carpet' 'Clay' 'Grass' 'Greenset']
# C:\Users\BPX Michał Dziedziak\AppData\Local\Temp\ipykernel_18344\3221986537.py:1: DtypeWarning: Columns (13) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('./../data/wta.csv')

# %%
# initialize data
dic = {}

periods = ['all', 'last_year', 'last_month']

for player in players:
    for surface in surfaces:
        for period in periods:
            key = f"{player}_{surface}_{period}"
            dic[key] = {
                'Player': player,
                'Surface': surface,
                'Period': period,
                'Matches': 0,
                'Wins': 0,
                'Losses': 0,
                'WinRate': 0.0,
                'Elo': 1500.0,
            }

# %%
def check_dic_key(key, player, surface, period):
    if key not in dic:
        dic[key] = {
            'Player': player,
            'Surface': surface,
            'Period': period,
            'Matches': 0,
            'Wins': 0,
            'Losses': 0,
            'WinRate': 0.0,
            'Elo': 1500.0,
        }
            
def calculate_elo_change(p1_elo, p2_elo, winner: int):
    k = 32
    # k = 256
    expected_p1 = 1 / (1 + 10 ** ((p2_elo - p1_elo) / 400))
    expected_p2 = 1 - expected_p1
    if winner == 1:
        p1_new = p1_elo + k * (1 - expected_p1)
        p2_new = p2_elo + k * (0 - expected_p2)
    else:
        p1_new = p1_elo + k * (0 - expected_p1)
        p2_new = p2_elo + k * (1 - expected_p2)
    return p1_new, p2_new

def update_data(period, row):
    player1 = row['Player_1']
    player2 = row['Player_2']
    surface = row['Surface']
    winner = row['Winner']

    key1 = f"{player1}_{surface}_{period}"
    key2 = f"{player2}_{surface}_{period}"

    # check_dic_key(key1, player1, surface, period)
    # check_dic_key(key2, player2, surface, period)

    dic[key1]['Matches'] += 1
    dic[key2]['Matches'] += 1

    if winner == player1:
        dic[key1]['Wins'] += 1
        dic[key2]['Losses'] += 1
        dic[key1]['WinRate'] = dic[key1]['Wins'] / dic[key1]['Matches']
        dic[key2]['WinRate'] = dic[key2]['Losses'] / dic[key2]['Matches']
        p1_elo, p2_elo = calculate_elo_change(dic[key1].get('Elo', 1500), dic[key2].get('Elo', 1500), 1)
    else:
        dic[key2]['Wins'] += 1
        dic[key1]['Losses'] += 1
        dic[key2]['WinRate'] = dic[key2]['Wins'] / dic[key2]['Matches']
        dic[key1]['WinRate'] = dic[key1]['Losses'] / dic[key1]['Matches']
        p2_elo, p1_elo = calculate_elo_change(dic[key2].get('Elo', 1500), dic[key1].get('Elo', 1500), 0)

    dic[key1]['Elo'] = p1_elo
    dic[key2]['Elo'] = p2_elo

# %%
last_month = CURRENT_DATE - dt.timedelta(days=30)
last_year = CURRENT_DATE - dt.timedelta(days=365)

for index, row in df.iterrows():
    periods_to_update = []

    if row['Date'] >= last_month:
        periods_to_update.append('last_month')
    if row['Date'] >= last_year:
        periods_to_update.append('last_year')
    periods_to_update.append('all')
    
    for per in periods_to_update:
        update_data(per, row)

# %%
players_data = pd.DataFrame.from_dict(dic, orient='index')
players_data.to_csv('./../data/players_data.csv', index=False)

tmp = players_data[players_data['Period']=='last_month'].sort_values(by='Elo', ascending=False).head(10)
print(tb.tabulate(tmp, headers='keys', tablefmt='psql'))
# Out:
# +---------------------------------+----------------+-----------+------------+-----------+--------+----------+-----------+---------+
# |                                 | Player         | Surface   | Period     |   Matches |   Wins |   Losses |   WinRate |     Elo |
# |---------------------------------+----------------+-----------+------------+-----------+--------+----------+-----------+---------|
# | Linette M._Grass_last_month     | Linette M.     | Grass     | last_month |         6 |      3 |        3 |  0.5      | 1557.85 |
# | Fernandez L.A._Grass_last_month | Fernandez L.A. | Grass     | last_month |         8 |      4 |        4 |  0.5      | 1555.33 |
# | Ruse E.G._Grass_last_month      | Ruse E.G.      | Grass     | last_month |         6 |      4 |        2 |  0.333333 | 1552.31 |
# | Volynets K._Grass_last_month    | Volynets K.    | Grass     | last_month |         3 |      1 |        2 |  0.666667 | 1543.39 |
# | Swiatek I._Grass_last_month     | Swiatek I.     | Grass     | last_month |        11 |     10 |        1 |  0.909091 | 1539.56 |
# | Anisimova A._Grass_last_month   | Anisimova A.   | Grass     | last_month |        15 |     12 |        3 |  0.2      | 1537.24 |
# | Osaka N._Grass_last_month       | Osaka N.       | Grass     | last_month |         6 |      3 |        3 |  0.5      | 1535.62 |
# | Mertens E._Grass_last_month     | Mertens E.     | Grass     | last_month |        10 |      8 |        2 |  0.2      | 1533.5  |
# | Zheng Q._Grass_last_month       | Zheng Q.       | Grass     | last_month |         4 |      2 |        2 |  0.5      | 1532.95 |
# | Kalinskaya A._Grass_last_month  | Kalinskaya A.  | Grass     | last_month |         2 |      1 |        1 |  0.5      | 1532.58 |
# +---------------------------------+----------------+-----------+------------+-----------+--------+----------+-----------+---------+
